# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKPARATKAR/LLM-GEN-AI/blob/main/StagesOfBuildingLLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Stage 1-**
#
# * Data Preprocessing and Sampaling
#
# * Attention Mechanism - WHat is multihead , masked and positional attentions.
#
# * LLM Architecture
#
#
# **Stage 2-**
#
# * Pretraining
#
# * Model Evaluation - Weight saving and loading , pretrained weights from OpenAI.
#
# * Foundational Model pretrained on unlabelled data.
#
# **Stage 3-**
#
# * Finetunning Using Langchain , Ollama . Finetunning a LLM foundational model is important to create a production level LLM applications. Finetunned LLMs can outperform just pretrained LLms on specific taks.
#
# * Building of spam or not-spam model which is classifier model.
#
# * Building personal assistant like chatbot.

# %% [markdown]
# Original Transformer had Encoder and Decoder blocks.
#
# GPT model has Decoder,No encoder.
#
# While LLMs are only trained for prediction of next word , but shows emergent properties like ability to classify , translate and summarize texts.

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)
